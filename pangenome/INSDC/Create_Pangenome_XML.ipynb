# %% [markdown]
# # Create Pangenome XML <a class="tocSkip">
# 12 Aug 2022; Julian
#
# **Code to create an XML to submit pangenomes as "analysis" objects to ENA. This notebook relies on a Google Sheet to have all of the neccesary information that will go into the XML. The Year1 data can be found [here](https://docs.google.com/spreadsheets/d/169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU/edit#gid=472507643).**
#
# **Note that the Analysis XSD and instructions on uploading the XML can be found [here](https://ena-docs.readthedocs.io/en/latest/submit/analyses.html), but the XSD does not currently reflect the new Pangenone requirements. If needed, you can view the Pangenome metadata proposal [here](https://docs.google.com/document/d/1610m__E0yLPo3lkad2vOonH1AO6BCyjkR7qajc7pSVY/edit?usp=sharing).**

# %% [markdown]
# # Preparation

# %%
import xml.etree.ElementTree as ET
from xml.dom import minidom
import pandas as pd
import os

# %%
## Sample to write XML for (must match column names in Google sheets)
file_to_write = "hprc-v1.0-mc-grch38"

# %%
# Get the Google billing project name and workspace name for current workspace
PROJECT = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE =os.path.basename(os.path.dirname(os.getcwd()))
bucket = os.environ['WORKSPACE_BUCKET'] + "/"


# Verify that we've captured the environment variables
print("Billing project: " + PROJECT)
print("Workspace: " + WORKSPACE)
print("Workspace storage bucket: " + bucket)
# Out:
# Billing project: human-pangenome-ucsc
# Workspace: AnVIL_HPRC_Data_Transfer
# Workspace storage bucket: gs://fc-cba31066-5983-4306-b66e-bdcfb644fb32/

# %% [markdown]
# # Function Definitions

# %%
def create_assembly_el(assembly_acc: str):
    """
    returns element:
    <ASSEMBLY>
        <STANDARD accession=assembly_acc/>
    </ASSEMBLY>  
    """
    assembly_el   = ET.Element("ASSEMBLY")

    standard_el   = ET.Element("STANDARD")
    standard_el.set('accession', assembly_acc)
    
    assembly_el.append(standard_el)

    return assembly_el

# %%
def create_analysis_attribute_el(tag_str: str, value_str: str):
    """
    returns element:
    <ANALYSIS_ATTRIBUTE>
        <TAG>tag_str</TAG>
        <VALUE>value_str</VALUE>
    </ANALYSIS_ATTRIBUTE>  
    """
    analysis_attribute_el   = ET.Element("ANALYSIS_ATTRIBUTE")

    attribute_tag_el        = ET.Element("TAG")
    attribute_tag_el.text      = tag_str

    attribute_value_el      = ET.Element("VALUE")
    attribute_value_el.text = value_str

    analysis_attribute_el.append(attribute_tag_el)
    analysis_attribute_el.append(attribute_value_el)

    return analysis_attribute_el

# %% [markdown]
# # Create Analysis Element

# %% [markdown]
# ## Pull In  Analysis Elements Info (Except SAMPLE_REF)

# %%
## Read in table with analysis info data
sheet_id = "169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU"
sheet_name = "analysis"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
analysis_df = pd.read_csv(url)

# %%
analysis_df.head()
# Out:
#     field name                          hprc-v1.0-minigraph-chm13  \
# 0        TITLE        HPRC Minigraph Pangenome (CHM13 based) v1.0
# 1  DESCRIPTION  Human Pangenome Reference Consortium (HPRC) pa...
# 2    STUDY_REF                                         PRJEB55385
# 3     filename                   hprc-v1.0-minigraph-chm13.gfa.gz
# 4     filetype                                                gfa
#
#                           hprc-v1.0-minigraph-grch38  \
# 0       HPRC Minigraph Pangenome (GRCh38 based) v1.0
# 1  Human Pangenome Reference Consortium (HPRC) pa...
# 2                                         PRJEB55386
# 3                  hprc-v1.0-minigraph-grch38.gfa.gz
# 4                                                gfa
#
#                                   hprc-v1.0-mc-chm13  \
# 0  HPRC Minigraph-CACTUS Pangenome (CHM13 based) ...
# 1  Human Pangenome Reference Consortium (HPRC) pa...
# 2                                         PRJEB55387
# 3                          hprc-v1.0-mc-chm13.gfa.gz
# 4                                                gfa
#
#                                  hprc-v1.0-mc-grch38  \
# 0  HPRC Minigraph-CACTUS Pangenome (GRCh38 based)...
# 1  Human Pangenome Reference Consortium (HPRC) pa...
# 2                                         PRJEB55388
# 3                         hprc-v1.0-mc-grch38.gfa.gz
# 4                                                gfa
#
#                                       hprc-v1.0-pggb
# 0                           HPRC PGGB Pangenome v1.0
# 1  Human Pangenome Reference Consortium (HPRC) pa...
# 2                                         PRJEB54791
# 3                              hprc-v1.0-pggb.gfa.gz
# 4                                                gfa

# %%
## Need to set index
analysis_df = analysis_df.set_index('field name')

# %% [markdown]
# ## Create Analysis Elements (Except SAMPLE_REF)

# %%
## Just pull column for sample we are going to write
sample_analysis_df = analysis_df[file_to_write]

# %%
## Get values that we will write
alias           = file_to_write
title           = sample_analysis_df['TITLE']
descr           = sample_analysis_df['DESCRIPTION']
study_acc       = sample_analysis_df['STUDY_REF']
filename        = sample_analysis_df['filename']
filetype        = sample_analysis_df['filetype']
checksum_method = sample_analysis_df['checksum_method']
checksum        = sample_analysis_df['checksum']

# %%
## Create TITLE element
title_el      = ET.Element("TITLE")
title_el.text = title


## Create DESCRIPTION element
descr_el      = ET.Element("DESCRIPTION")
descr_el.text = descr


## Create STUDY_REF element
studyref_el      = ET.Element("STUDY_REF")
studyref_el.set('accession', study_acc)


## Create FILE & FILES elements (nest FILE inside FILES)
file_el  = ET.Element("FILE")
file_el.set('filename', filename)
file_el.set('filetype', filetype)
file_el.set('checksum', checksum)
file_el.set('checksum_method', checksum_method)

files_el = ET.Element("FILES")
files_el.append(file_el)

# %%
## Add sub elements to ANALYSIS element
## Note that we will add FILES element later (needs to go after SAMPLE_REF AND ASSEMBLY)
analysis_el = ET.Element("ANALYSIS")
analysis_el.set('alias', alias)

analysis_el.append(title_el)
analysis_el.append(descr_el)
analysis_el.append(studyref_el)

# %% [markdown]
# ## Pull In SAMPLE_REF Info

# %%
## Read in table with BioSample IDs
sheet_id = "169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU"
sheet_name = "samples"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
sample_df = pd.read_csv(url)

# %%
sample_df.head()
# Out:
#     sample     biosample
# 0  HG00438  SAMN17861652
# 1  HG00621  SAMN17861653
# 2  HG00673  SAMN17861654
# 3  HG00735  SAMN17861655
# 4  HG00741  SAMN17861656

# %% [markdown]
# ## Create SAMPLE_REF Elements

# %%
for index, row in sample_df.iterrows():

    biosample_id = row['biosample']

    sampleref_el      = ET.Element("SAMPLE_REF")
    sampleref_el.set('accession', biosample_id)
    
    analysis_el.append(sampleref_el)

# %% [markdown]
# ## Pull in Assembly Accessions

# %%
## Read in table with BioSample IDs
sheet_id = "169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU"
sheet_name = "assemblies"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
assembly_df = pd.read_csv(url)

# %%
assembly_df.head()
# Out:
#     sample        accession      note
# 0  HG00438  GCA_018471515.1  maternal
# 1  HG00621  GCA_018472605.1  maternal
# 2  HG00673  GCA_018472565.1  maternal
# 3  HG00735  GCA_018472765.1  maternal
# 4  HG00741  GCA_018471095.1  maternal

# %% [markdown]
# ## Create ANALYSIS_TYPE, ASSEMBLY_GRAPH, and ASSEMBLY Elements

# %%
## We are putting the pangenome under ASSEMBLY_GRAPH
pangenome_graph_el = ET.Element("ASSEMBLY_GRAPH")

# %%
for index, row in assembly_df.iterrows():

    accession = row['accession']

    assembly_el = create_assembly_el(accession)
    
    pangenome_graph_el.append(assembly_el)

# %%
analysis_type_el   = ET.Element("ANALYSIS_TYPE")
analysis_type_el.append(pangenome_graph_el)

# %%
## NOW we can add files element
analysis_el.append(analysis_type_el)
analysis_el.append(files_el)

# %% [markdown]
# # Create Analysis Attributes Elements

# %% [markdown]
# Create analysis attributes element

# %%
analysis_attributes_el = ET.Element("ANALYSIS_ATTRIBUTES")

# %% [markdown]
# ## Add Analysis Attributes

# %%
## Read in table with analysis attributes
sheet_id = "169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU"
sheet_name = "analysis_attributes"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
anal_attr_df = pd.read_csv(url)

# %%
anal_attr_df.head()
# Out:
#                       TAG                                              VALUE  \
# 0         number of nodes   Number of segments, or S lines, in the GFA file.
# 1    number of components                  Connected components in the graph
# 2         number of edges  Number of edges/links (GFA L lines) in the pan...
# 3             length (bp)  Total number of nucleotides in the nodes/segme...
# 4  total path length (bp)  Number of bases in all paths included in the g...
#
#      Rules        example     Required hprc-v1.0-minigraph-chm13  \
# 0  numeric        424,643  recommended                    493631
# 1  numeric             25  recommended                        25
# 2  numeric        637,628  recommended                    738529
# 3  numeric  3,239,764,787  recommended                3365688482
# 4  numeric  3,239,764,787  recommended                       NaN
#
#   hprc-v1.0-minigraph-grch38 hprc-v1.0-mc-chm13 hprc-v1.0-mc-grch38  \
# 0                     424643           85591995            81751614
# 1                        194               2445                2624
# 2                     637628          118409526           113258931
# 3                 3239764787         3324657754          3287932785
# 4                        NaN       257143252360        254821009311
#
#   hprc-v1.0-pggb
# 0      110884673
# 1             25
# 2      154756169
# 3     8415267572
# 4   271199380512

# %%
anal_attr_df = anal_attr_df.set_index('TAG')

# %% [markdown]
# ## Loop through attributes and add ANALYSIS_ATTRIBUTEs

# %%
for index, row in anal_attr_df.iterrows():
    tag_name  = row.name
    tag_value = row[file_to_write]
    
    if not pd.isna(tag_value):

        analysis_attribute_el = create_analysis_attribute_el(tag_name, tag_value)
        analysis_attributes_el.append(analysis_attribute_el)

# %% [markdown]
# ## Add (Common) Sample Names

# %%
## Read in table with common/Coriell sample names
sheet_id = "169OS-mKkR7qLzE5kzkHWob2bJckLhQbUuMxeH7i_upU"
sheet_name = "samples"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
sample_df = pd.read_csv(url)

# %%
sample_df.head()
# Out:
#     sample     biosample
# 0  HG00438  SAMN17861652
# 1  HG00621  SAMN17861653
# 2  HG00673  SAMN17861654
# 3  HG00735  SAMN17861655
# 4  HG00741  SAMN17861656

# %% [markdown]
# ## Loop through samples and add as ANALYSIS_ATTRIBUTEs

# %%
for index, row in sample_df.iterrows():
    sample_name = row['sample']
    sample_name_el = create_analysis_attribute_el("sample name", sample_name)
    
    analysis_attributes_el.append(sample_name_el)

# %%
# Create Final Tree

# %%
## Old way
## Add ANALYSIS_ATTRIBUTES to ANALYSIS_SET (root element)
# analysis_set_el = ET.Element("ANALYSIS_SET")

# analysis_set_el.append(analysis_el)
# analysis_set_el.append(analysis_attributes_el)

# %%
## Add ANALYSIS_ATTRIBUTES to ANALYSIS_SET (root element)
analysis_set_el = ET.Element("ANALYSIS_SET")

analysis_el.append(analysis_attributes_el)
analysis_set_el.append(analysis_el)

# %% [markdown]
# # Write, Check, & Upload

# %% [markdown]
# ## Write XML File

# %%
write_name = f"{file_to_write}.xml"

xmlstr = minidom.parseString(ET.tostring(analysis_set_el, encoding='UTF-8')).toprettyxml(indent="   ")
with open(write_name, "w") as f:
    f.write(xmlstr)

# %% [markdown]
# ## Check results

# %%
! cat {write_name}
# Out:
# <?xml version="1.0" ?>
# <ANALYSIS_SET>
#    <ANALYSIS alias="hprc-v1.0-mc-grch38">
#       <TITLE>HPRC Minigraph-CACTUS Pangenome (GRCh38 based) v1.0</TITLE>
#       <DESCRIPTION>Human Pangenome Reference Consortium (HPRC) pangenome built with the minigraph-CACTUS pipeline from 88 year 1 assemblies plus GRCh38 (included as the reference assembly) and CHM13.</DESCRIPTION>
#       <STUDY_REF accession="PRJEB55388"/>
#       <SAMPLE_REF accession="SAMN17861652"/>
#       <SAMPLE_REF accession="SAMN17861653"/>
#       <SAMPLE_REF accession="SAMN17861654"/>
#       <SAMPLE_REF accession="SAMN17861655"/>
#       <SAMPLE_REF accession="SAMN17861656"/>
#       <SAMPLE_REF accession="SAMN17861657"/>
#       <SAMPLE_REF accession="SAMN17861658"/>
#       <SAMPLE_REF accession="SAMN17861232"/>
#       <SAMPLE_REF accession="SAMN17861659"/>
#       <SAMPLE_REF accession="SAMN17861233"/>
#       <SAMPLE_REF accession="SAMN17861234"/>
#       <SAMPLE_REF accession="SAMN17861235"/>
#       <SAMPLE_REF accession="SAMN17861236"/>
#       <SAMPLE_REF accession="SAMN17861660"/>
#       <SAMPLE_REF accession="SAMN17861661"/>
#       <SAMPLE_REF accession="SAMN17861662"/>
#       <SAMPLE_REF accession="SAMN17861663"/>
#       <SAMPLE_REF accession="SAMN17861237"/>
#       <SAMPLE_REF accession="SAMN17861238"/>
#       <SAMPLE_REF accession="SAMN17861239"/>
#       <SAMPLE_REF accession="SAMN17861240"/>
#       <SAMPLE_REF accession="SAMN17861664"/>
#       <SAMPLE_REF accession="SAMN17861665"/>
#       <SAMPLE_REF accession="SAMN17861666"/>
#       <SAMPLE_REF accession="SAMN17861667"/>
#       <SAMPLE_REF accession="SAMN17861668"/>
#       <SAMPLE_REF accession="SAMN17861241"/>
#       <SAMPLE_REF accession="SAMN17861670"/>
#       <SAMPLE_REF accession="SAMN17861671"/>
#       <SAMPLE_REF accession="SAMN00006581"/>
#       <SAMPLE_REF accession="SAMN12162846"/>
#       <SAMPLE_REF accession="SAMN13957917"/>
#       <SAMPLE_REF accession="SAMN12162856"/>
#       <SAMPLE_REF accession="SAMN13957942"/>
#       <SAMPLE_REF accession="SAMN13958415"/>
#       <SAMPLE_REF accession="SAMN13961514"/>
#       <SAMPLE_REF accession="SAMN13958364"/>
#       <SAMPLE_REF accession="SAMN05603745"/>
#       <SAMPLE_REF accession="SAMN13957944"/>
#       <SAMPLE_REF accession="SAMN08723473"/>
#       <SAMPLE_REF accession="SAMN13958363"/>
#       <SAMPLE_REF accession="SAMN13957875"/>
#       <SAMPLE_REF accession="SAMN13207712"/>
#       <SAMPLE_REF accession="SAMN11308573"/>
#       <SAMPLE_REF accession="SAMN03255769"/>
#       <SAMPLE_REF accession="SAMN12121739"/>
#       <ANALYSIS_TYPE>
#          <ASSEMBLY_GRAPH>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471515.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472605.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472565.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472765.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471095.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472685.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471345.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469665.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471085.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469405.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469865.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469685.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018467155.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472695.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471545.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472865.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471535.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018466845.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018467015.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018466985.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018470445.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469875.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469955.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469935.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018470455.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472855.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469425.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018473295.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472825.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018506975.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504365.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504375.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018506125.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504085.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018505825.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018852585.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504065.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503585.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018506165.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503525.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018505845.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503255.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504635.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504655.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472595.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472575.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472585.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472715.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471105.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472725.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471075.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469695.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471065.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469675.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469965.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469705.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018467165.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472705.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471555.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472845.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018471525.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018466835.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018467005.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018466855.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018470435.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469925.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469945.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018470425.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018470465.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018473305.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018469415.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018473315.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018472835.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018506955.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504645.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504045.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018505855.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504055.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018505865.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018852595.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504075.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503575.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018506155.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503245.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018505835.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018503285.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504625.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_018504665.1"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_009914755.3"/>
#             </ASSEMBLY>
#             <ASSEMBLY>
#                <STANDARD accession="GCA_000001405.15"/>
#             </ASSEMBLY>
#          </ASSEMBLY_GRAPH>
#       </ANALYSIS_TYPE>
#       <FILES>
#          <FILE checksum="8e34e9eadd6c4c52d2be6771d17c79bf" checksum_method="MD5" filename="hprc-v1.0-mc-grch38.gfa.gz" filetype="gfa"/>
#       </FILES>
#       <ANALYSIS_ATTRIBUTES>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>number of nodes</TAG>
#             <VALUE>81751614</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>number of components</TAG>
#             <VALUE>2624</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>number of edges</TAG>
#             <VALUE>113258931</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>length (bp)</TAG>
#             <VALUE>3287932785</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>total path length (bp)</TAG>
#             <VALUE>254821009311</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>number of paths</TAG>
#             <VALUE>27036</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>number of path steps</TAG>
#             <VALUE>4410833806</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>primary reference assembly</TAG>
#             <VALUE>GCA_000001405.15</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>reference based</TAG>
#             <VALUE>true</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>cyclic</TAG>
#             <VALUE>true</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>cyclic reference</TAG>
#             <VALUE>false</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>masked region types</TAG>
#             <VALUE>centromeres, mitochondrial DNA</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>masking procedure</TAG>
#             <VALUE>DNA-BRNN</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>graph type</TAG>
#             <VALUE>pangenome</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>pangenome name</TAG>
#             <VALUE>hprc-v1.0-mc-grch38</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>file format version</TAG>
#             <VALUE>GFAv1.1</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>pipeline</TAG>
#             <VALUE>Minigraph-CACTUS</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>resolution</TAG>
#             <VALUE>base level</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00438</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00621</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00673</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00735</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00741</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01071</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01106</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01123</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01175</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01258</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01358</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01361</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01891</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01928</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01952</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01978</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02148</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02257</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02486</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02559</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02572</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02622</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02630</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02717</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02886</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03453</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03516</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03540</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03579</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG00733</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01109</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG01243</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02055</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02080</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02109</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02145</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02723</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG02818</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03098</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03486</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>HG03492</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>NA18906</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>NA20129</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>NA21309</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>CHM13</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#          <ANALYSIS_ATTRIBUTE>
#             <TAG>sample name</TAG>
#             <VALUE>GRCh38</VALUE>
#          </ANALYSIS_ATTRIBUTE>
#       </ANALYSIS_ATTRIBUTES>
#    </ANALYSIS>
# </ANALYSIS_SET>

# %% [markdown]
# ## Upload To Bucket

# %%
! gsutil cp {write_name} {bucket}Y1_Pangenome_XML/{write_name}
# Out:
# Copying file://hprc-v1.0-mc-grch38.xml [Content-Type=application/xml]...
# / [1 files][ 20.0 KiB/ 20.0 KiB]
# Operation completed over 1 objects/20.0 KiB.

# %%
print(f"{bucket}Y1_Pangenome_XML/{write_name}")
# Out:
# gs://fc-cba31066-5983-4306-b66e-bdcfb644fb32/Y1_Pangenome_XML/hprc-v1.0-mc-grch38.xml
